# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
df = pd.read_excel("global_cars_enhanced.xlsx")
df.head()
# Out:
#   global_cars_enhanced Unnamed: 1        Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0               Car_ID      Brand  Manufacture_Year  Body_Type  Fuel_Type
# 1             CAR_0001   Mercedes              2006        SUV     Petrol
# 2             CAR_0002     Nissan              2023      Coupe     Petrol
# 3             CAR_0003     Nissan              2007  Hatchback     Diesel
# 4             CAR_0004     Nissan              2013      Coupe     Petrol
#
#      Unnamed: 5 Unnamed: 6  Unnamed: 7        Unnamed: 8 Unnamed: 9  \
# 0  Transmission  Engine_CC  Horsepower  Mileage_km_per_l  Price_USD
# 1        Manual       4089         547                17      73407
# 2     Automatic       4618         167                25      79370
# 3        Manual       1802         110                16      76549
# 4        Manual       1835         373                16      48722
#
#              Unnamed: 10 Unnamed: 11     Unnamed: 12 Unnamed: 13  \
# 0  Manufacturing_Country     Car_Age  Price_Category   HP_per_CC
# 1                    USA          20         Premium      0.1338
# 2                    USA           3         Premium      0.0362
# 3                  China          19         Premium       0.061
# 4                    USA          13       Mid-Range      0.2033
#
#     Unnamed: 14       Unnamed: 15
# 0  Age_Category  Efficiency_Score
# 1           Old              0.35
# 2           New              0.75
# 3           Old               0.3
# 4           Old               0.3

# %%
# set first row as column names
df.columns = df.iloc[0]

# drop the first row
df = df.drop(0)

# reset index
df = df.reset_index(drop=True)

df.head()
# Out:
# 0    Car_ID     Brand Manufacture_Year  Body_Type Fuel_Type Transmission  \
# 0  CAR_0001  Mercedes             2006        SUV    Petrol       Manual
# 1  CAR_0002    Nissan             2023      Coupe    Petrol    Automatic
# 2  CAR_0003    Nissan             2007  Hatchback    Diesel       Manual
# 3  CAR_0004    Nissan             2013      Coupe    Petrol       Manual
# 4  CAR_0005   Hyundai             2009  Hatchback    Hybrid    Automatic
#
# 0 Engine_CC Horsepower Mileage_km_per_l Price_USD Manufacturing_Country  \
# 0      4089        547               17     73407                   USA
# 1      4618        167               25     79370                   USA
# 2      1802        110               16     76549                 China
# 3      1835        373               16     48722                   USA
# 4      2332        145               28     83265                    UK
#
# 0 Car_Age Price_Category HP_per_CC Age_Category Efficiency_Score
# 0      20        Premium    0.1338          Old             0.35
# 1       3        Premium    0.0362          New             0.75
# 2      19        Premium     0.061          Old              0.3
# 3      13      Mid-Range    0.2033          Old              0.3
# 4      17        Premium    0.0622          Old              0.9

# %% [markdown]
# Correct column names
# Because the first row in the file is the column names, but Pandas treats it as data.
# Therefore, we leave the first row as column names, and delete it from the data.

# %% [markdown]
# Check Missing Values

# %%
print(df.isna())
# Out:
# 0    Car_ID  Brand  Manufacture_Year  Body_Type  Fuel_Type  Transmission  \
# 0     False  False             False      False      False         False
# 1     False  False             False      False      False         False
# 2     False  False             False      False      False         False
# 3     False  False             False      False      False         False
# 4     False  False             False      False      False         False
# ..      ...    ...               ...        ...        ...           ...
# 295   False  False             False      False      False         False
# 296   False  False             False      False      False         False
# 297   False  False             False      False      False         False
# 298   False  False             False      False      False         False
# 299   False  False             False      False      False         False
#
# 0    Engine_CC  Horsepower  Mileage_km_per_l  Price_USD  \
# 0        False       False             False      False
# 1        False       False             False      False
# 2        False       False             False      False
# 3        False       False             False      False
# 4        False       False             False      False
# ..         ...         ...               ...        ...
# 295      False       False             False      False
# 296      False       False             False      False
# 297      False       False             False      False
# 298      False       False             False      False
# 299      False       False             False      False
#
# 0    Manufacturing_Country  Car_Age  Price_Category  HP_per_CC  Age_Category  \
# 0                    False    False           False      False         False
# 1                    False    False           False      False         False
# 2                    False    False           False      False         False
# 3                    False    False           False      False         False
# 4                    False    False           False      False         False
# ..                     ...      ...             ...        ...           ...
# 295                  False    False           False      False         False
# 296                  False    False           False      False         False
# 297                  False    False           False      False         False
# 298                  False    False           False      False         False
# 299                  False    False           False      False         False
#
# 0    Efficiency_Score
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ..                ...
# 295             False
# 296             False
# 297             False
# 298             False
# 299             False
#
# [300 rows x 16 columns]

# %%
print(df.isna().sum())
# Out:
# 0
# Car_ID                   0
# Brand                    0
# Manufacture_Year         0
# Body_Type                0
# Fuel_Type                0
# Transmission             0
# Engine_CC                0
# Horsepower               0
# Mileage_km_per_l         0
# Price_USD                0
# Manufacturing_Country    0
# Car_Age                  0
# Price_Category           0
# HP_per_CC                0
# Age_Category             0
# Efficiency_Score         0
# dtype: int64

# %%
# checking duplicate rows
df.duplicated()[df.duplicated()==True]
# Out:
# Series([], dtype: bool)

# %%
# finding number of rows and columns

print("Shape (rows, columns): ", df.shape,"\n")

print("number of rows: ", df.shape[0])
print("number of columns: ", df.shape[1])
# Out:
# Shape (rows, columns):  (300, 16)
#
# number of rows:  300
# number of columns:  16

# %%
# viewing the data types of columns
df.dtypes
# Out:
# 0
# Car_ID                   object
# Brand                    object
# Manufacture_Year         object
# Body_Type                object
# Fuel_Type                object
# Transmission             object
# Engine_CC                object
# Horsepower               object
# Mileage_km_per_l         object
# Price_USD                object
# Manufacturing_Country    object
# Car_Age                  object
# Price_Category           object
# HP_per_CC                object
# Age_Category             object
# Efficiency_Score         object
# dtype: object

# %%
df['Manufacture_Year'] = pd.to_numeric(df['Manufacture_Year'])
df['Engine_CC'] = pd.to_numeric(df['Engine_CC'])
df['Horsepower'] = pd.to_numeric(df['Horsepower'])
df['Mileage_km_per_l'] = pd.to_numeric(df['Mileage_km_per_l'])
df['Price_USD'] = pd.to_numeric(df['Price_USD'])
df['Car_Age'] = pd.to_numeric(df['Car_Age'])
df['HP_per_CC'] = pd.to_numeric(df['HP_per_CC'])
df['Efficiency_Score'] = pd.to_numeric(df['Efficiency_Score'])

df.dtypes
# Out:
# 0
# Car_ID                    object
# Brand                     object
# Manufacture_Year           int64
# Body_Type                 object
# Fuel_Type                 object
# Transmission              object
# Engine_CC                  int64
# Horsepower                 int64
# Mileage_km_per_l           int64
# Price_USD                  int64
# Manufacturing_Country     object
# Car_Age                    int64
# Price_Category            object
# HP_per_CC                float64
# Age_Category              object
# Efficiency_Score         float64
# dtype: object

# %% [markdown]
# ### Descriptive summary Statistics

# %%
# Statistical summary
df.describe(include='all')
# Out:
# 0         Car_ID   Brand  Manufacture_Year Body_Type Fuel_Type Transmission  \
# count        300     300        300.000000       300       300          300
# unique       300      10               NaN         5         4            2
# top     CAR_0001  Nissan               NaN     Sedan    Petrol       Manual
# freq           1      41               NaN        70        77          155
# mean         NaN     NaN       2015.123333       NaN       NaN          NaN
# std          NaN     NaN          5.966023       NaN       NaN          NaN
# min          NaN     NaN       2005.000000       NaN       NaN          NaN
# 25%          NaN     NaN       2010.000000       NaN       NaN          NaN
# 50%          NaN     NaN       2015.000000       NaN       NaN          NaN
# 75%          NaN     NaN       2020.000000       NaN       NaN          NaN
# max          NaN     NaN       2025.000000       NaN       NaN          NaN
#
# 0         Engine_CC  Horsepower  Mileage_km_per_l      Price_USD  \
# count    300.000000  300.000000        300.000000     300.000000
# unique          NaN         NaN               NaN            NaN
# top             NaN         NaN               NaN            NaN
# freq            NaN         NaN               NaN            NaN
# mean    3052.880000  328.346667         19.716667   60848.823333
# std     1117.937497  153.202644          6.028061   34445.525598
# min     1001.000000   70.000000         10.000000    5221.000000
# 25%     2074.000000  188.250000         15.000000   29418.500000
# 50%     3117.500000  329.500000         19.500000   59179.500000
# 75%     3964.000000  454.750000         24.000000   89692.250000
# max     4994.000000  599.000000         30.000000  119587.000000
#
# 0      Manufacturing_Country     Car_Age Price_Category   HP_per_CC  \
# count                    300  300.000000            300  300.000000
# unique                     6         NaN              4         NaN
# top                  Germany         NaN         Budget         NaN
# freq                      55         NaN             78         NaN
# mean                     NaN   10.876667            NaN    0.129559
# std                      NaN    5.966023            NaN    0.093239
# min                      NaN    1.000000            NaN    0.017800
# 25%                      NaN    6.000000            NaN    0.063250
# 50%                      NaN   11.000000            NaN    0.106850
# 75%                      NaN   16.000000            NaN    0.168325
# max                      NaN   21.000000            NaN    0.525500
#
# 0      Age_Category  Efficiency_Score
# count           300        300.000000
# unique            4               NaN
# top             Old               NaN
# freq            126               NaN
# mean            NaN          0.485833
# std             NaN          0.301403
# min             NaN          0.000000
# 25%             NaN          0.250000
# 50%             NaN          0.475000
# 75%             NaN          0.700000
# max             NaN          1.000000

# %% [markdown]
# Univariate Analysis:

# %% [markdown]
# 1-Distribution of car prices

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Price_USD'], bins=20)
plt.title("Distribution of Car Prices")
plt.show()

# %% [markdown]
# 2-Engine power distribution

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Horsepower'], bins=20)
plt.title("Distribution of Horsepower")
plt.show()

# %% [markdown]
# Bivariate Analysis:

# %% [markdown]
# 1-Average price depending on fuel type

# %%
fuel_price = df.groupby('Fuel_Type')['Price_USD'].mean()

plt.figure(figsize=(8,5))
fuel_price.plot(kind='bar')
plt.title("Average Price by Fuel Type")
plt.ylabel("Average Price (USD)")
plt.show()

# %% [markdown]
# 2-Price depends on the company

# %%
brand_price = df.groupby('Brand')['Price_USD'].mean().sort_values(ascending=False)

plt.figure(figsize=(10,5))
brand_price.plot(kind='bar')
plt.title("Average Price by Brand")
plt.ylabel("Average Price (USD)")
plt.show()

# %% [markdown]
# Price vs engine power

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='Horsepower', y='Price_USD', data=df)
plt.title("Horsepower vs Price")
plt.show()

# %% [markdown]
# Correlation Matrix

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df[['Engine_CC', 'Horsepower']].corr(), annot=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# Time-Based Analysis

# %%
year_price = df.groupby('Manufacture_Year')['Price_USD'].mean()

plt.figure(figsize=(10,5))
year_price.plot()
plt.title("Average Car Price by Manufacture Year")
plt.ylabel("Average Price (USD)")
plt.show()
